# %%
import pandas as pd

df=pd.read_csv(r'/Users/Annu/Prwatech Python/nyc_wheather.csv')
df.head
df.tail(30)
df
# Out:
#             T  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df['Temperature'][df['Events']=='Rain']
# Out:
# 8     44
# 9     50
# 15    47
# 26    41
# Name: Temperature, dtype: int64

# %%
#NAN: not a number
print("Events",df.Events)
print("Humidity",df.Humidity)
print("Events count",df.Events.count)

print("coulmns",df.columns)
print("count",df.count()) #column wise record count
print("shape",df.shape)
print("temperature",df.Temperature.count) #individual column count
df.describe() #it will give details of matrix #will give details of only numerical data
# Out:
# Events 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8         Rain
# 9         Rain
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15        Rain
# 16    Fog-Snow
# 17        Snow
# 18         NaN
# 19         NaN
# 20         NaN
# 21        Snow
# 22    Fog-Snow
# 23        Snow
# 24         NaN
# 25         NaN
# 26        Rain
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# Name: Events, dtype: object
# Humidity 0     52
# 1     46
# 2     47
# 3     44
# 4     41
# 5     35
# 6     33
# 7     64
# 8     77
# 9     71
# 10    37
# 11    53
# 12    42
# 13    47
# 14    62
# 15    70
# 16    66
# 17    53
# 18    42
# 19    49
# 20    45
# 21    41
# 22    78
# 23    53
# 24    54
# 25    56
# 26    45
# 27    51
# 28    50
# 29    46
# 30    52
# Name: Humidity, dtype: int64
# ...

# %%
df.WindSpeedMPH #showing NAN values and non values
print(df.WindSpeedMPH.isna()) #row 10,11,12 are NAN
print(df.WindSpeedMPH.isna().sum()) #isna() will tell how many NAN is availabe in that column
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# Name: WindSpeedMPH, dtype: bool
# 3

# %%
df.dtypes #column T
# Out:
# T                        object
# Temperature               int64
# DewPoint                  int64
# Humidity                  int64
# Sea Level PressureIn    float64
# VisibilityMiles           int64
# WindSpeedMPH            float64
# PrecipitationIn          object
# CloudCover                int64
# Events                   object
# WindDirDegrees            int64
# dtype: object

# %%
df.Events
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8         Rain
# 9         Rain
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15        Rain
# 16    Fog-Snow
# 17        Snow
# 18         NaN
# 19         NaN
# 20         NaN
# 21        Snow
# 22    Fog-Snow
# 23        Snow
# 24         NaN
# 25         NaN
# 26        Rain
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# Name: Events, dtype: object

# %%
df.Events.unique() #unique content will give unique values available in that particular column
# Out:
# array([nan, 'Rain', 'Fog-Snow', 'Snow'], dtype=object)

# %%
df.Events.describe()
# Out:
# count        9
# unique       3
# top       Rain
# freq         4
# Name: Events, dtype: object

# %%
df['Temperature'].max() #maximum
# Out:
# 50

# %%
df.Temperature.min() #minimum
# Out:
# 20

# %%
df.Temperature.describe()
# Out:
# count    31.000000
# mean     34.677419
# std       7.639315
# min      20.000000
# 25%      29.000000
# 50%      35.000000
# 75%      39.500000
# max      50.000000
# Name: Temperature, dtype: float64

# %%
df1=df['Temperature']>30
df1 
df1.sum() #total nmber of temperature more than 30
df1.head()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# Name: Temperature, dtype: bool

# %%
#to which day it rains
df['T'][df['Events']=='Rain']
df['T'][df['Events']=='Snow']
# Out:
# 17    1/18/2016
# 21    1/22/2016
# 23    1/24/2016
# Name: T, dtype: object

# %%
df['T'][df['Humidity']==70]
df['T'][df['Humidity']>=70]
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 22    1/23/2016
# Name: T, dtype: object

# %%
df['T'][df['WindSpeedMPH']==7.0]
# Out:
# 1      1/2/2016
# 15    1/16/2016
# 25    1/26/2016
# 26    1/27/2016
# 29    1/30/2016
# Name: T, dtype: object
